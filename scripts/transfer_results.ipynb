# %%
import anndata as ad
from pathlib import Path
from scETM import evaluate
import scanpy as sc
import numpy as np
import pandas as pd
from collections import defaultdict
from sklearn.metrics import pairwise_distances
sc.set_figure_params(fontsize=10, figsize=(10, 10), dpi=120, dpi_save=250)

# %%
root = Path('../results/transfer')

# %%
for fpath in root.glob("*.h5ad"):
    adata = ad.read_h5ad(fpath)
    for name in ('delta', 'theta'):
        print(f'{fpath.name}_{name}')
        evaluate(adata, name, resolutions=[0.01, 0.02, 0.03, 0.045, 0.067, 0.10, 0.15, 0.23, 0.34], plot_dir=str(root), plot_fname=f'{fpath.name}_{name}')
# Out:
# 9] INFO - scETM.eval_utils: Resolution:  0.02	ARI:  0.4125	NMI:  0.5040	bARI:  0.1142	# labels: 2
# [2021-04-30 21:40:44,043] INFO - scETM.eval_utils: Resolution:  0.03	ARI:  0.7999	NMI:  0.7571	bARI:  0.0670	# labels: 4
# [2021-04-30 21:40:44,260] INFO - scETM.eval_utils: Resolution: 0.045	ARI:  0.8707	NMI:  0.8288	bARI:  0.0647	# labels: 5
# [2021-04-30 21:40:44,466] INFO - scETM.eval_utils: Resolution: 0.067	ARI:  0.8751	NMI:  0.8319	bARI:  0.0659	# labels: 5
# [2021-04-30 21:40:44,641] INFO - scETM.eval_utils: Resolution:   0.1	ARI:  0.9358	NMI:  0.8805	bARI:  0.0548	# labels: 6
# [2021-04-30 21:40:44,834] INFO - scETM.eval_utils: Resolution:  0.15	ARI:  0.9372	NMI:  0.8819	bARI:  0.0550	# labels: 6
# [2021-04-30 21:40:45,013] INFO - scETM.eval_utils: Resolution:  0.23	ARI:  0.9372	NMI:  0.8819	bARI:  0.0550	# labels: 6
# [2021-04-30 21:40:45,225] INFO - scETM.eval_utils: Resolution:  0.34	ARI:  0.8589	NMI:  0.8543	bARI:  0.0706	# labels: 9
# [2021-04-30 21:40:45,226] INFO - scETM.eval_utils: Calculating batch mixing entropy...
# [2021-04-30 21:40:54,867] INFO - scETM.eval_utils: delta_BE:  0.3404
# [2021-04-30 21:40:54,867] INFO - scETM.eval_utils: Calculating kbet...
# [2021-04-30 21:41:01,304] INFO - scETM.eval_utils: delta_kBET:  0.3097
# [2021-04-30 21:41:06,384] INFO - scETM.logging_utils: evaluate(AnnData object with n_obs × n_vars = 1886 × 13263
#     obs: 'batch_indices', 'cell_id', 'cell_types', 'barcode', 'leiden_0.01', 'leiden_0.02', 'leiden_0.03', 'leiden_0.045', 'leiden_0.067', 'leiden_0.1', 'leiden_0.15', 'leiden_0.23', 'leiden_0.34'
#     uns: 'neighbors', 'leiden', 'umap', 'leiden_0.15_colors', 'batch_indices_colors', 'cell_types_colors'
#     obsm: 'delta', 'recon_log', 'theta', 'knn_indices', 'X_umap'
#     obsp: 'distances', 'connectivities', theta, resolutions = [0.01, 0.02, 0.03, 0.045, 0.067, 0.1, 0.15, 0.23, 0.34], plot_dir = ..\results\transfer, plot_fname = FACS_MP_scETM_seed2_04_23-01_06_53.h5ad_theta)
# [2021-04-30 21:41:06,503] INFO - scETM.eval_utils: Performing leiden clustering
# FACS_MP_scETM_seed2_04_23-01_06_53.h5ad_theta
# [2021-04-30 21:41:06,666] INFO - scETM.eval_utils: Resolution:  0.01	ARI:  0.4028	NMI:  0.4867	bARI:  0.1222	# labels: 2
# [2021-04-30 21:41:06,807] INFO - scETM.eval_utils: Resolution:  0.02	ARI:  0.4028	NMI:  0.4867	bARI:  0.1222	# labels: 2
# [2021-04-30 21:41:06,946] INFO - scETM.eval_utils: Resolution:  0.03	ARI:  0.7636	NMI:  0.7061	bARI:  0.0710	# labels: 3
# [2021-04-30 21:41:07,124] INFO - scETM.eval_utils: Resolution: 0.045	ARI:  0.8552	NMI:  0.8118	bARI:  0.0675	# labels: 5
# [2021-04-30 21:41:07,265] INFO - scETM.eval_utils: Resolution: 0.067	ARI:  0.8552	NMI:  0.8118	bARI:  0.0675	# labels: 5
# [2021-04-30 21:41:07,444] INFO - scETM.eval_utils: Resolution:   0.1	ARI:  0.8586	NMI:  0.8150	bARI:  0.0681	# labels: 5
# [2021-04-30 21:41:07,586] INFO - scETM.eval_utils: Resolution:  0.15	ARI:  0.8593	NMI:  0.8149	bARI:  0.0681	# labels: 5
# [2021-04-30 21:41:07,721] INFO - scETM.eval_utils: Resolution:  0.23	ARI:  0.9137	NMI:  0.8534	bARI:  0.0548	# labels: 6
# [2021-04-30 21:41:07,946] INFO - scETM.eval_utils: Resolution:  0.34	ARI:  0.8214	NMI:  0.8362	bARI:  0.0630	# labels: 9
# [2021-04-30 21:41:07,947] INFO - scETM.eval_utils: Calculating batch mixing entropy...
# [2021-04-30 21:41:17,274] INFO - scETM.eval_utils: theta_BE:  0.3361
# [2021-04-30 21:41:17,275] INFO - scETM.eval_utils: Calculating kbet...
# [2021-04-30 21:41:23,867] INFO - scETM.eval_utils: theta_kBET:  0.2922
# [2021-04-30 21:41:29,112] INFO - scETM.logging_utils: evaluate(AnnData object with n_obs × n_vars = 1886 × 13263
#     obs: 'batch_indices', 'cell_id', 'cell_types', 'barcode'
#     obsm: 'delta', 'recon_log', 'theta', delta, resolutions = [0.01, 0.02, 0.03, 0.045, 0.067, 0.1, 0.15, 0.23, 0.34], plot_dir = ..\results\transfer, plot_fname = FACS_MP_scETM_seed3_04_22-13_13_41.h5ad_delta)
# [2021-04-30 21:41:29,232] INFO - scETM.eval_utils: Performing leiden clustering
# FACS_MP_scETM_seed3_04_22-13_13_41.h5ad_delta
# [2021-04-30 21:41:29,344] INFO - scETM.eval_utils: Resolution:  0.01	ARI:  0.4007	NMI:  0.4851	bARI:  0.1200	# labels: 2
# [2021-04-30 21:41:29,489] INFO - scETM.eval_utils: Resolution:  0.02	ARI:  0.4169	NMI:  0.5347	bARI:  0.1210	# labels: 3
# [2021-04-30 21:41:29,661] INFO - scETM.eval_utils: Resolution:  0.03	ARI:  0.6381	NMI:  0.6890	bARI:  0.0698	# labels: 4
# [2021-04-30 21:41:29,804] INFO - scETM.eval_utils: Resolution: 0.045	ARI:  0.7900	NMI:  0.7418	bARI:  0.0703	# labels: 4
# [2021-04-30 21:41:29,951] INFO - scETM.eval_utils: Resolution: 0.067	ARI:  0.8572	NMI:  0.8134	bARI:  0.0669	# labels: 5
# [2021-04-30 21:41:30,097] INFO - scETM.eval_utils: Resolution:   0.1	ARI:  0.9165	NMI:  0.8574	bARI:  0.0571	# labels: 6
# [2021-04-30 21:41:30,278] INFO - scETM.eval_utils: Resolution:  0.15	ARI:  0.9391	NMI:  0.8809	bARI:  0.0522	# labels: 8
# [2021-04-30 21:41:30,427] INFO - scETM.eval_utils: Resolution:  0.23	ARI:  0.9418	NMI:  0.8834	bARI:  0.0525	# labels: 8
# [2021-04-30 21:41:30,575] INFO - scETM.eval_utils: Resolution:  0.34	ARI:  0.9418	NMI:  0.8834	bARI:  0.0525	# labels: 8
# [2021-04-30 21:41:30,577] INFO - scETM.eval_utils: Calculating batch mixing entropy...
# [2021-04-30 21:41:39,655] INFO - scETM.eval_utils: delta_BE:  0.3613
# [2021-04-30 21:41:39,655] INFO - scETM.eval_utils: Calculating kbet...
# [2021-04-30 21:41:46,142] INFO - scETM.eval_utils: delta_kBET:  0.3765
# [2021-04-30 21:41:51,190] INFO - scETM.logging_utils: evaluate(AnnData object with n_obs × n_vars = 1886 × 13263
#     obs: 'batch_indices', 'cell_id', 'cell_types', 'barcode', 'leiden_0.01', 'leiden_0.02', 'leiden_0.03', 'leiden_0.045', 'leiden_0.067', 'leiden_0.1', 'leiden_0.15', 'leiden_0.23', 'leiden_0.34'
#     uns: 'neighbors', 'leiden', 'umap', 'leiden_0.23_colors', 'batch_indices_colors', 'cell_types_colors'
#     obsm: 'delta', 'recon_log', 'theta', 'knn_indices', 'X_umap'
#     obsp: 'distances', 'connectivities', theta, resolutions = [0.01, 0.02, 0.03, 0.045, 0.067, 0.1, 0.15, 0.23, 0.34], plot_dir = ..\results\transfer, plot_fname = FACS_MP_scETM_seed3_04_22-13_13_41.h5ad_theta)
# [2021-04-30 21:41:51,313] INFO - scETM.eval_utils: Performing leiden clustering
# FACS_MP_scETM_seed3_04_22-13_13_41.h5ad_theta
# [2021-04-30 21:41:51,417] INFO - scETM.eval_utils: Resolution:  0.01	ARI:  0.4012	NMI:  0.4857	bARI:  0.1200	# labels: 2
# [2021-04-30 21:41:51,518] INFO - scETM.eval_utils: Resolution:  0.02	ARI:  0.4012	NMI:  0.4857	bARI:  0.1200	# labels: 2
# [2021-04-30 21:41:51,617] INFO - scETM.eval_utils: Resolution:  0.03	ARI:  0.4012	NMI:  0.4857	bARI:  0.1200	# labels: 2
# [2021-04-30 21:41:51,717] INFO - scETM.eval_utils: Resolution: 0.045	ARI:  0.4012	NMI:  0.4857	bARI:  0.1200	# labels: 2
# [2021-04-30 21:41:51,876] INFO - scETM.eval_utils: Resolution: 0.067	ARI:  0.6252	NMI:  0.6687	bARI:  0.0698	# labels: 4
# [2021-04-30 21:41:52,060] INFO - scETM.eval_utils: Resolution:   0.1	ARI:  0.8449	NMI:  0.7806	bARI:  0.0580	# labels: 5
# [2021-04-30 21:41:52,275] INFO - scETM.eval_utils: Resolution:  0.15	ARI:  0.8574	NMI:  0.8027	bARI:  0.0584	# labels: 6
# [2021-04-30 21:41:52,403] INFO - scETM.eval_utils: Resolution:  0.23	ARI:  0.7623	NMI:  0.7613	bARI:  0.0579	# labels: 6
# [2021-04-30 21:41:52,654] INFO - scETM.eval_utils: Resolution:  0.34	ARI:  0.6491	NMI:  0.7662	bARI:  0.0470	# labels: 9
# [2021-04-30 21:41:52,657] INFO - scETM.eval_utils: Calculating batch mixing entropy...
# [2021-04-30 21:42:01,823] INFO - scETM.eval_utils: theta_BE:  0.4136
# [2021-04-30 21:42:01,824] INFO - scETM.eval_utils: Calculating kbet...
# [2021-04-30 21:42:08,320] INFO - scETM.eval_utils: theta_kBET:  0.4443
# [2021-04-30 21:42:13,422] INFO - scETM.logging_utils: evaluate(AnnData object with n_obs × n_vars = 1886 × 13263
#     obs: 'batch_indices', 'cell_id', 'cell_types', 'barcode'
#     obsm: 'delta', 'recon_log', 'theta', delta, resolutions = [0.01, 0.02, 0.03, 0.045, 0.067, 0.1, 0.15, 0.23, 0.34], plot_dir = ..\results\transfer, plot_fname = MousePancreas_FACS_scETM_seed1_04_30-07_31_06.h5ad_delta)
# [2021-04-30 21:42:13,547] INFO - scETM.eval_utils: Performing leiden clustering
# MousePancreas_FACS_scETM_seed1_04_30-07_31_06.h5ad_delta
# [2021-04-30 21:42:13,659] INFO - scETM.eval_utils: Resolution:  0.01	ARI:  0.4009	NMI:  0.4824	bARI:  0.1207	# labels: 2
# [2021-04-30 21:42:13,772] INFO - scETM.eval_utils: Resolution:  0.02	ARI:  0.4009	NMI:  0.4824	bARI:  0.1207	# labels: 2
# [2021-04-30 21:42:13,914] INFO - scETM.eval_utils: Resolution:  0.03	ARI:  0.6511	NMI:  0.7256	bARI:  0.0669	# labels: 4
# [2021-04-30 21:42:14,059] INFO - scETM.eval_utils: Resolution: 0.045	ARI:  0.7072	NMI:  0.7740	bARI:  0.0605	# labels: 5
# [2021-04-30 21:42:14,230] INFO - scETM.eval_utils: Resolution: 0.067	ARI:  0.9125	NMI:  0.8429	bARI:  0.0561	# labels: 5
# [2021-04-30 21:42:14,407] INFO - scETM.eval_utils: Resolution:   0.1	ARI:  0.9256	NMI:  0.8558	bARI:  0.0534	# labels: 5
# [2021-04-30 21:42:14,584] INFO - scETM.eval_utils: Resolution:  0.15	ARI:  0.9220	NMI:  0.8598	bARI:  0.0509	# labels: 8
# [2021-04-30 21:42:14,761] INFO - scETM.eval_utils: Resolution:  0.23	ARI:  0.8584	NMI:  0.8546	bARI:  0.0717	# labels: 10
# [2021-04-30 21:42:14,939] INFO - scETM.eval_utils: Resolution:  0.34	ARI:  0.5998	NMI:  0.7891	bARI:  0.1567	# labels: 11
# [2021-04-30 21:42:14,940] INFO - scETM.eval_utils: Calculating batch mixing entropy...
# [2021-04-30 21:42:24,426] INFO - scETM.eval_utils: delta_BE:  0.2707
# [2021-04-30 21:42:24,427] INFO - scETM.eval_utils: Calculating kbet...
# [2021-04-30 21:42:30,917] INFO - scETM.eval_utils: delta_kBET:  0.2434
# [2021-04-30 21:42:36,242] INFO - scETM.logging_utils: evaluate(AnnData object with n_obs × n_vars = 1886 × 13263
#     obs: 'batch_indices', 'cell_id', 'cell_types', 'barcode', 'leiden_0.01', 'leiden_0.02', 'leiden_0.03', 'leiden_0.045', 'leiden_0.067', 'leiden_0.1', 'leiden_0.15', 'leiden_0.23', 'leiden_0.34'
#     uns: 'neighbors', 'leiden', 'umap', 'leiden_0.1_colors', 'batch_indices_colors', 'cell_types_colors'
#     obsm: 'delta', 'recon_log', 'theta', 'knn_indices', 'X_umap'
#     obsp: 'distances', 'connectivities', theta, resolutions = [0.01, 0.02, 0.03, 0.045, 0.067, 0.1, 0.15, 0.23, 0.34], plot_dir = ..\results\transfer, plot_fname = MousePancreas_FACS_scETM_seed1_04_30-07_31_06.h5ad_theta)
# [2021-04-30 21:42:36,355] INFO - scETM.eval_utils: Performing leiden clustering
# MousePancreas_FACS_scETM_seed1_04_30-07_31_06.h5ad_theta
# [2021-04-30 21:42:36,478] INFO - scETM.eval_utils: Resolution:  0.01	ARI:  0.0000	NMI:  0.0000	bARI:  0.0000	# labels: 1
# [2021-04-30 21:42:36,646] INFO - scETM.eval_utils: Resolution:  0.02	ARI:  0.3936	NMI:  0.5300	bARI:  0.0021	# labels: 3
# [2021-04-30 21:42:36,811] INFO - scETM.eval_utils: Resolution:  0.03	ARI:  0.3936	NMI:  0.5300	bARI:  0.0021	# labels: 3
# [2021-04-30 21:42:36,980] INFO - scETM.eval_utils: Resolution: 0.045	ARI:  0.6496	NMI:  0.6926	bARI:  0.0608	# labels: 4
# [2021-04-30 21:42:37,147] INFO - scETM.eval_utils: Resolution: 0.067	ARI:  0.6624	NMI:  0.7038	bARI:  0.0580	# labels: 5
# [2021-04-30 21:42:37,349] INFO - scETM.eval_utils: Resolution:   0.1	ARI:  0.5536	NMI:  0.6817	bARI:  0.1303	# labels: 6
# [2021-04-30 21:42:37,513] INFO - scETM.eval_utils: Resolution:  0.15	ARI:  0.4846	NMI:  0.6579	bARI:  0.1671	# labels: 7
# [2021-04-30 21:42:37,740] INFO - scETM.eval_utils: Resolution:  0.23	ARI:  0.5486	NMI:  0.7053	bARI:  0.1698	# labels: 10
# [2021-04-30 21:42:37,906] INFO - scETM.eval_utils: Resolution:  0.34	ARI:  0.5164	NMI:  0.7338	bARI:  0.1357	# labels: 12
# [2021-04-30 21:42:37,907] INFO - scETM.eval_utils: Calculating batch mixing entropy...
# [2021-04-30 21:42:47,095] INFO - scETM.eval_utils: theta_BE:  0.2672
# [2021-04-30 21:42:47,095] INFO - scETM.eval_utils: Calculating kbet...
# [2021-04-30 21:42:53,491] INFO - scETM.eval_utils: theta_kBET:  0.2312
# [2021-04-30 21:42:58,673] INFO - scETM.logging_utils: evaluate(AnnData object with n_obs × n_vars = 1886 × 13263
#     obs: 'batch_indices', 'cell_id', 'cell_types', 'barcode'
#     obsm: 'delta', 'recon_log', 'theta', delta, resolutions = [0.01, 0.02, 0.03, 0.045, 0.067, 0.1, 0.15, 0.23, 0.34], plot_dir = ..\results\transfer, plot_fname = MousePancreas_FACS_scETM_seed2_04_30-07_31_20.h5ad_delta)
# [2021-04-30 21:42:58,789] INFO - scETM.eval_utils: Performing leiden clustering
# MousePancreas_FACS_scETM_seed2_04_30-07_31_20.h5ad_delta
# [2021-04-30 21:42:58,937] INFO - scETM.eval_utils: Resolution:  0.01	ARI:  0.4146	NMI:  0.5128	bARI:  0.1106	# labels: 2
# [2021-04-30 21:42:59,150] INFO - scETM.eval_utils: Resolution:  0.02	ARI:  0.5925	NMI:  0.6517	bARI:  0.0630	# labels: 3
# [2021-04-30 21:42:59,296] INFO - scETM.eval_utils: Resolution:  0.03	ARI:  0.5925	NMI:  0.6517	bARI:  0.0630	# labels: 3
# [2021-04-30 21:42:59,506] INFO - scETM.eval_utils: Resolution: 0.045	ARI:  0.6629	NMI:  0.7441	bARI:  0.0638	# labels: 4
# [2021-04-30 21:42:59,683] INFO - scETM.eval_utils: Resolution: 0.067	ARI:  0.9210	NMI:  0.8553	bARI:  0.0531	# labels: 5
# [2021-04-30 21:42:59,863] INFO - scETM.eval_utils: Resolution:   0.1	ARI:  0.9210	NMI:  0.8553	bARI:  0.0531	# labels: 5
# [2021-04-30 21:43:00,042] INFO - scETM.eval_utils: Resolution:  0.15	ARI:  0.9325	NMI:  0.8715	bARI:  0.0527	# labels: 6
# [2021-04-30 21:43:00,217] INFO - scETM.eval_utils: Resolution:  0.23	ARI:  0.8639	NMI:  0.8519	bARI:  0.0719	# labels: 8
# [2021-04-30 21:43:00,395] INFO - scETM.eval_utils: Resolution:  0.34	ARI:  0.8218	NMI:  0.8253	bARI:  0.0626	# labels: 9
# [2021-04-30 21:43:00,396] INFO - scETM.eval_utils: Calculating batch mixing entropy...
# [2021-04-30 21:43:09,522] INFO - scETM.eval_utils: delta_BE:  0.2993
# [2021-04-30 21:43:09,523] INFO - scETM.eval_utils: Calculating kbet...
# [2021-04-30 21:43:16,133] INFO - scETM.eval_utils: delta_kBET:  0.2656
# [2021-04-30 21:43:21,479] INFO - scETM.logging_utils: evaluate(AnnData object with n_obs × n_vars = 1886 × 13263
#     obs: 'batch_indices', 'cell_id', 'cell_types', 'barcode', 'leiden_0.01', 'leiden_0.02', 'leiden_0.03', 'leiden_0.045', 'leiden_0.067', 'leiden_0.1', 'leiden_0.15', 'leiden_0.23', 'leiden_0.34'
#     uns: 'neighbors', 'leiden', 'umap', 'leiden_0.15_colors', 'batch_indices_colors', 'cell_types_colors'
#     obsm: 'delta', 'recon_log', 'theta', 'knn_indices', 'X_umap'
#     obsp: 'distances', 'connectivities', theta, resolutions = [0.01, 0.02, 0.03, 0.045, 0.067, 0.1, 0.15, 0.23, 0.34], plot_dir = ..\results\transfer, plot_fname = MousePancreas_FACS_scETM_seed2_04_30-07_31_20.h5ad_theta)
# [2021-04-30 21:43:21,602] INFO - scETM.eval_utils: Performing leiden clustering
# MousePancreas_FACS_scETM_seed2_04_30-07_31_20.h5ad_theta
# [2021-04-30 21:43:21,717] INFO - scETM.eval_utils: Resolution:  0.01	ARI:  0.1457	NMI:  0.2822	bARI:  0.0132	# labels: 2
# [2021-04-30 21:43:21,872] INFO - scETM.eval_utils: Resolution:  0.02	ARI:  0.3764	NMI:  0.5402	bARI: -0.0013	# labels: 3
# [2021-04-30 21:43:22,019] INFO - scETM.eval_utils: Resolution:  0.03	ARI:  0.6472	NMI:  0.7410	bARI:  0.0572	# labels: 5
# [2021-04-30 21:43:22,202] INFO - scETM.eval_utils: Resolution: 0.045	ARI:  0.6472	NMI:  0.7410	bARI:  0.0572	# labels: 5
# [2021-04-30 21:43:22,412] INFO - scETM.eval_utils: Resolution: 0.067	ARI:  0.5818	NMI:  0.7121	bARI:  0.0844	# labels: 6
# [2021-04-30 21:43:22,613] INFO - scETM.eval_utils: Resolution:   0.1	ARI:  0.7455	NMI:  0.7568	bARI:  0.0622	# labels: 7
# [2021-04-30 21:43:22,784] INFO - scETM.eval_utils: Resolution:  0.15	ARI:  0.5042	NMI:  0.7113	bARI:  0.1571	# labels: 8
# [2021-04-30 21:43:23,021] INFO - scETM.eval_utils: Resolution:  0.23	ARI:  0.5288	NMI:  0.7228	bARI:  0.1591	# labels: 10
# [2021-04-30 21:43:23,228] INFO - scETM.eval_utils: Resolution:  0.34	ARI:  0.5449	NMI:  0.7421	bARI:  0.1565	# labels: 12
# [2021-04-30 21:43:23,229] INFO - scETM.eval_utils: Calculating batch mixing entropy...
# [2021-04-30 21:43:32,727] INFO - scETM.eval_utils: theta_BE:  0.2704
# [2021-04-30 21:43:32,728] INFO - scETM.eval_utils: Calculating kbet...
# [2021-04-30 21:43:39,623] INFO - scETM.eval_utils: theta_kBET:  0.2264
# [2021-04-30 21:43:45,020] INFO - scETM.logging_utils: evaluate(AnnData object with n_obs × n_vars = 1886 × 13263
#     obs: 'batch_indices', 'cell_id', 'cell_types', 'barcode'
#     obsm: 'delta', 'recon_log', 'theta', delta, resolutions = [0.01, 0.02, 0.03, 0.045, 0.067, 0.1, 0.15, 0.23, 0.34], plot_dir = ..\results\transfer, plot_fname = MousePancreas_FACS_scETM_seed3_04_30-07_31_11.h5ad_delta)
# [2021-04-30 21:43:45,138] INFO - scETM.eval_utils: Performing leiden clustering
# MousePancreas_FACS_scETM_seed3_04_30-07_31_11.h5ad_delta
# [2021-04-30 21:43:45,253] INFO - scETM.eval_utils: Resolution:  0.01	ARI:  0.0000	NMI:  0.0000	bARI:  0.0000	# labels: 1
# [2021-04-30 21:43:45,406] INFO - scETM.eval_utils: Resolution:  0.02	ARI:  0.4116	NMI:  0.5049	bARI:  0.1128	# labels: 2
# [2021-04-30 21:43:45,586] INFO - scETM.eval_utils: Resolution:  0.03	ARI:  0.5895	NMI:  0.6449	bARI:  0.0644	# labels: 3
# [2021-04-30 21:43:45,782] INFO - scETM.eval_utils: Resolution: 0.045	ARI:  0.6440	NMI:  0.6904	bARI:  0.0644	# labels: 4
# [2021-04-30 21:43:45,936] INFO - scETM.eval_utils: Resolution: 0.067	ARI:  0.7058	NMI:  0.7736	bARI:  0.0602	# labels: 5
# [2021-04-30 21:43:46,089] INFO - scETM.eval_utils: Resolution:   0.1	ARI:  0.9292	NMI:  0.8678	bARI:  0.0524	# labels: 6
# [2021-04-30 21:43:46,275] INFO - scETM.eval_utils: Resolution:  0.15	ARI:  0.9452	NMI:  0.8908	bARI:  0.0527	# labels: 7
# [2021-04-30 21:43:46,469] INFO - scETM.eval_utils: Resolution:  0.23	ARI:  0.7654	NMI:  0.8313	bARI:  0.0533	# labels: 8
# [2021-04-30 21:43:46,742] INFO - scETM.eval_utils: Resolution:  0.34	ARI:  0.6004	NMI:  0.7873	bARI:  0.1598	# labels: 10
# [2021-04-30 21:43:46,743] INFO - scETM.eval_utils: Calculating batch mixing entropy...
# [2021-04-30 21:43:56,357] INFO - scETM.eval_utils: delta_BE:  0.2892
# [2021-04-30 21:43:56,358] INFO - scETM.eval_utils: Calculating kbet...
# [2021-04-30 21:44:03,102] INFO - scETM.eval_utils: delta_kBET:  0.2370
# [2021-04-30 21:44:08,302] INFO - scETM.logging_utils: evaluate(AnnData object with n_obs × n_vars = 1886 × 13263
#     obs: 'batch_indices', 'cell_id', 'cell_types', 'barcode', 'leiden_0.01', 'leiden_0.02', 'leiden_0.03', 'leiden_0.045', 'leiden_0.067', 'leiden_0.1', 'leiden_0.15', 'leiden_0.23', 'leiden_0.34'
#     uns: 'neighbors', 'leiden', 'umap', 'leiden_0.15_colors', 'batch_indices_colors', 'cell_types_colors'
#     obsm: 'delta', 'recon_log', 'theta', 'knn_indices', 'X_umap'
#     obsp: 'distances', 'connectivities', theta, resolutions = [0.01, 0.02, 0.03, 0.045, 0.067, 0.1, 0.15, 0.23, 0.34], plot_dir = ..\results\transfer, plot_fname = MousePancreas_FACS_scETM_seed3_04_30-07_31_11.h5ad_theta)
# [2021-04-30 21:44:08,422] INFO - scETM.eval_utils: Performing leiden clustering
# MousePancreas_FACS_scETM_seed3_04_30-07_31_11.h5ad_theta
# [2021-04-30 21:44:08,538] INFO - scETM.eval_utils: Resolution:  0.01	ARI:  0.0000	NMI:  0.0000	bARI:  0.0000	# labels: 1
# [2021-04-30 21:44:08,711] INFO - scETM.eval_utils: Resolution:  0.02	ARI:  0.1464	NMI:  0.2853	bARI: -0.0083	# labels: 2
# [2021-04-30 21:44:08,881] INFO - scETM.eval_utils: Resolution:  0.03	ARI:  0.3831	NMI:  0.5530	bARI: -0.0016	# labels: 3
# [2021-04-30 21:44:09,108] INFO - scETM.eval_utils: Resolution: 0.045	ARI:  0.6850	NMI:  0.7228	bARI:  0.0597	# labels: 4
# [2021-04-30 21:44:09,282] INFO - scETM.eval_utils: Resolution: 0.067	ARI:  0.6082	NMI:  0.6928	bARI:  0.0841	# labels: 5
# [2021-04-30 21:44:09,494] INFO - scETM.eval_utils: Resolution:   0.1	ARI:  0.7402	NMI:  0.7382	bARI:  0.0533	# labels: 6
# [2021-04-30 21:44:09,748] INFO - scETM.eval_utils: Resolution:  0.15	ARI:  0.5675	NMI:  0.7442	bARI:  0.1711	# labels: 9
# [2021-04-30 21:44:09,928] INFO - scETM.eval_utils: Resolution:  0.23	ARI:  0.5645	NMI:  0.7390	bARI:  0.1728	# labels: 10
# [2021-04-30 21:44:10,100] INFO - scETM.eval_utils: Resolution:  0.34	ARI:  0.4897	NMI:  0.7147	bARI:  0.1429	# labels: 11
# [2021-04-30 21:44:10,102] INFO - scETM.eval_utils: Calculating batch mixing entropy...
# [2021-04-30 21:44:19,501] INFO - scETM.eval_utils: theta_BE:  0.2708
# [2021-04-30 21:44:19,502] INFO - scETM.eval_utils: Calculating kbet...
# [2021-04-30 21:44:26,188] INFO - scETM.eval_utils: theta_kBET:  0.2169

# %%
def silhouette(intra, inter):
    intra_mean, inter_mean = intra.mean(), inter.mean()
    max_mean = max(intra_mean, inter_mean)
    return (inter_mean - intra_mean) / max_mean

def get_silhouette(adata, name1, name2):
    if isinstance(name1, str):
        name1 = [name1]
    if isinstance(name2, str):
        name2 = [name2]

    mask1, mask2 = adata.obs.cell_types.apply(lambda t: t in name1), adata.obs.cell_types.apply(lambda t: t in name2)
    n1 = mask1.sum()
    sliced_adata = adata[adata.obs_names[mask1].append(adata.obs_names[mask2])]

    result = dict()
    for mat, name in ((sliced_adata.X, 'X'), (sliced_adata.obsm['delta'], 'delta'), (sliced_adata.obsm['theta'], 'theta')):
        d = pairwise_distances(mat)
        d11, d22, d12, d21 = d[:n1, :n1], d[n1:, n1:], d[:n1, n1:], d[n1:, :n1]
        sh1 = silhouette(d11, d12).mean()
        sh2 = silhouette(d22, d21).mean()
        print(f'{name:5s} sh: {", ".join(name1)}: {sh1:8.5f}; {", ".join(name2)}: {sh2:8.5f}')
        result[f'{name};{", ".join(name1)}'], result[f'{name};{", ".join(name2)}'] = sh1, sh2
    return pd.DataFrame(result.values(), index=result.keys())

B_macro, T_macro = defaultdict(list), defaultdict(list)
for fpath in root.glob("*.h5ad"):
    print(f'===== Reading {fpath} =====')
    adata = ad.read_h5ad(fpath)
    beta_mask = adata.obs.cell_types == 'beta'

    # mean & std of the norm of pancreatic beta cells
    for mat, name in ((adata.X, 'X'), (adata.obsm['delta'], 'delta'), (adata.obsm['theta'], 'theta')):
        norm_beta_cells = np.linalg.norm(mat[beta_mask, :], axis=1)
        print(f'{name:5s} norm_beta_cells\tmean:{np.mean(norm_beta_cells):11.4g}\tstd:{np.std(norm_beta_cells):11.4g}')

    trained_dataset = fpath.name.split('_')[0]
    B_macro[trained_dataset].append(get_silhouette(adata, 'B_cell', 'macrophage'))
    T_macro[trained_dataset].append(get_silhouette(adata, 'T_cell', 'macrophage'))
# Out:
# ===== Reading ..\results\transfer\FACSWithoutPancreas_MP_scETM_seed1_04_23-01_09_00.h5ad =====
# X     norm_beta_cells	mean:       1560	std:       1040
# delta norm_beta_cells	mean:      18.16	std:      4.557
# theta norm_beta_cells	mean:     0.4037	std:    0.06401
# X     sh: B_cell:  0.53528; macrophage:  0.20938
# delta sh: B_cell:  0.41528; macrophage:  0.57005
# theta sh: B_cell:  0.32665; macrophage:  0.62917
# X     sh: T_cell:  0.69233; macrophage:  0.18929
# delta sh: T_cell:  0.36717; macrophage:  0.61127
# theta sh: T_cell:  0.39905; macrophage:  0.67471
# ===== Reading ..\results\transfer\FACSWithoutPancreas_MP_scETM_seed2_04_22-13_13_43.h5ad =====
# X     norm_beta_cells	mean:       1560	std:       1040
# delta norm_beta_cells	mean:       12.8	std:      3.315
# theta norm_beta_cells	mean:     0.4044	std:     0.1702
# X     sh: B_cell:  0.53528; macrophage:  0.20938
# delta sh: B_cell:  0.48809; macrophage:  0.57373
# theta sh: B_cell:  0.53028; macrophage:  0.59462
# X     sh: T_cell:  0.69233; macrophage:  0.18929
# delta sh: T_cell:  0.49150; macrophage:  0.60988
# theta sh: T_cell:  0.53585; macrophage:  0.63175
# ===== Reading ..\results\transfer\FACSWithoutPancreas_MP_scETM_seed3_04_22-13_13_43.h5ad =====
# X     norm_beta_cells	mean:       1560	std:       1040
# delta norm_beta_cells	mean:      14.47	std:      2.501
# theta norm_beta_cells	mean:     0.2874	std:    0.06081
# X     sh: B_cell:  0.53528; macrophage:  0.20938
# delta sh: B_cell:  0.51499; macrophage:  0.63335
# theta sh: B_cell:  0.48330; macrophage:  0.59707
# X     sh: T_cell:  0.69233; macrophage:  0.18929
# delta sh: T_cell:  0.46789; macrophage:  0.65171
# theta sh: T_cell:  0.50217; macrophage:  0.57730
# ===== Reading ..\results\transfer\FACS_MP_scETM_seed1_04_22-13_12_38.h5ad =====
# X     norm_beta_cells	mean:       1560	std:       1040
# delta norm_beta_cells	mean:      5.158	std:      0.395
# theta norm_beta_cells	mean:     0.1949	std:    0.01282
# X     sh: B_cell:  0.53528; macrophage:  0.20938
# delta sh: B_cell:  0.50118; macrophage:  0.61675
# theta sh: B_cell:  0.52099; macrophage:  0.65462
# X     sh: T_cell:  0.69233; macrophage:  0.18929
# delta sh: T_cell:  0.53930; macrophage:  0.60174
# theta sh: T_cell:  0.58621; macrophage:  0.61662
# ===== Reading ..\results\transfer\FACS_MP_scETM_seed2_04_23-01_06_53.h5ad =====
# X     norm_beta_cells	mean:       1560	std:       1040
# delta norm_beta_cells	mean:      4.411	std:     0.2052
# theta norm_beta_cells	mean:     0.1675	std:   0.003574
# X     sh: B_cell:  0.53528; macrophage:  0.20938
# delta sh: B_cell:  0.56106; macrophage:  0.61033
# theta sh: B_cell:  0.66215; macrophage:  0.68031
# X     sh: T_cell:  0.69233; macrophage:  0.18929
# delta sh: T_cell:  0.58146; macrophage:  0.62270
# theta sh: T_cell:  0.70075; macrophage:  0.67769
# ===== Reading ..\results\transfer\FACS_MP_scETM_seed3_04_22-13_13_41.h5ad =====
# X     norm_beta_cells	mean:       1560	std:       1040
# delta norm_beta_cells	mean:      5.238	std:     0.3087
# theta norm_beta_cells	mean:     0.2093	std:     0.0153
# X     sh: B_cell:  0.53528; macrophage:  0.20938
# delta sh: B_cell:  0.50654; macrophage:  0.61836
# theta sh: B_cell:  0.58296; macrophage:  0.63063
# X     sh: T_cell:  0.69233; macrophage:  0.18929
# delta sh: T_cell:  0.52279; macrophage:  0.59947
# theta sh: T_cell:  0.51592; macrophage:  0.59951
# ===== Reading ..\results\transfer\MousePancreas_FACS_scETM_seed1_04_30-07_31_06.h5ad =====
# X     norm_beta_cells	mean:       1560	std:       1040
# delta norm_beta_cells	mean:      4.782	std:     0.7421
# theta norm_beta_cells	mean:      0.168	std:    0.03151
# X     sh: B_cell:  0.53528; macrophage:  0.20938
# delta sh: B_cell:  0.15119; macrophage:  0.56349
# theta sh: B_cell:  0.06463; macrophage:  0.75541
# X     sh: T_cell:  0.69233; macrophage:  0.18929
# delta sh: T_cell:  0.17033; macrophage:  0.69423
# theta sh: T_cell:  0.00421; macrophage:  0.83036
# ===== Reading ..\results\transfer\MousePancreas_FACS_scETM_seed2_04_30-07_31_20.h5ad =====
# X     norm_beta_cells	mean:       1560	std:       1040
# delta norm_beta_cells	mean:      4.114	std:     0.5215
# theta norm_beta_cells	mean:     0.1625	std:    0.02096
# X     sh: B_cell:  0.53528; macrophage:  0.20938
# delta sh: B_cell:  0.04713; macrophage:  0.54014
# theta sh: B_cell:  0.01078; macrophage:  0.83773
# X     sh: T_cell:  0.69233; macrophage:  0.18929
# delta sh: T_cell:  0.03428; macrophage:  0.66112
# theta sh: T_cell:  0.03211; macrophage:  0.85908
# ===== Reading ..\results\transfer\MousePancreas_FACS_scETM_seed3_04_30-07_31_11.h5ad =====
# X     norm_beta_cells	mean:       1560	std:       1040
# delta norm_beta_cells	mean:      4.608	std:     0.5985
# theta norm_beta_cells	mean:     0.1658	std:     0.0236
# X     sh: B_cell:  0.53528; macrophage:  0.20938
# delta sh: B_cell:  0.10753; macrophage:  0.45163
# theta sh: B_cell:  0.06017; macrophage:  0.62902
# X     sh: T_cell:  0.69233; macrophage:  0.18929
# delta sh: T_cell:  0.15309; macrophage:  0.57333
# theta sh: T_cell:  0.10592; macrophage:  0.73407

# %%
for entries in (B_macro, T_macro):
    print('\n =====')
    for name, dfs in entries.items():
        df = pd.concat(dfs, axis=1).T
        print(name)
        df = df.describe().iloc[1:3, :].T
        df.index = df.index.map(lambda x: tuple(x.split(';')))
        print(df.unstack(1))
# Out:
#  =====
# FACSWithoutPancreas
#            mean                  std
#          B_cell macrophage    B_cell macrophage
# X      0.535284   0.209381  0.000000   0.000000
# delta  0.472786   0.592375  0.051582   0.035532
# theta  0.446744   0.606953  0.106624   0.019278
# FACS
#            mean                  std
#          B_cell macrophage    B_cell macrophage
# X      0.535284   0.209381  0.000000   0.000000
# delta  0.522926   0.615144  0.033135   0.004251
# theta  0.588698   0.655189  0.070755   0.024844
# MousePancreas
#            mean                  std
#          B_cell macrophage    B_cell macrophage
# X      0.535284   0.209381  0.000000   0.000000
# delta  0.101949   0.518422  0.052256   0.059006
# theta  0.045195   0.740718  0.029888   0.105129
#
#  =====
# FACSWithoutPancreas
#            mean                  std
#          T_cell macrophage    T_cell macrophage
# X      0.692327   0.189289  0.000000   0.000000
# delta  0.442187   0.624283  0.066026   0.023761
# theta  0.479021   0.627918  0.071274   0.048818
# FACS
#            mean                  std
#          T_cell macrophage    T_cell macrophage
# X      0.692327   0.189289  0.000000   0.000000
# delta  0.547848   0.607971  0.030259   0.012809
# theta  0.600956   0.631276  0.093294   0.041100
# MousePancreas
#            mean                  std
#          T_cell macrophage    T_cell macrophage
# X      0.692327   0.189289  0.000000   0.000000
# delta  0.119233   0.642893  0.074071   0.062479
# theta  0.047413   0.807838  0.052554   0.065479
